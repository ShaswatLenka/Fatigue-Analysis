# %%
import numpy as np
import pandas as pd


df = pd.read_csv("train.csv")

# %%
df.head(5)
# Out:
#        TIME    ID                     Patient         Date  Age(Yrs)  Ht(Cms)  \
# 0   8:00 AM  12.0  Tika                        31/05/2009       36.0    160.0
# 1  10:45 AM   8.0  Tika                        31/05/2009       36.0    160.0
# 2   1:30 PM   3.0  Tika                        30/05/2009       36.0    160.0
# 3   4:15 PM   4.0  Tika                        30/05/2009       36.0    160.0
# 4   7:00 PM   1.0  Tika                        30/05/2009       36.0    162.0
#
#    Wt(Kgs)   Sex      Smoker  FVC  (L)    ...      FEV3/FVC (%).1  \
# 0     72.0  Male  Non Smoker      2.54    ...                 NaN
# 1     72.0  Male  Non Smoker      2.55    ...                 NaN
# 2     72.0  Male  Non Smoker      2.68    ...                 NaN
# 3     72.0  Male  Non Smoker      2.72    ...                 NaN
# 4     68.0  Male  Non Smoker      3.01    ...                 NaN
#
#    FVC Time (Sec)  FVC Time (Sec).1  ExplTime (Sec)  MVV (L/min)  \
# ...
